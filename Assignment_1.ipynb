# %%
name = input("Enter student name: ")
student_class = input("Enter class: ")

m1 = float(input("Enter marks for Subject 1: "))
m2 = float(input("Enter marks for Subject 2: "))
m3 = float(input("Enter marks for Subject 3: "))
m4 = float(input("Enter marks for Subject 4: "))
m5 = float(input("Enter marks for Subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5

print("Result:")
print("Name:", name)
print("Class:", student_class)
print("Total Marks:", total)
print("Percentage:", percentage)
# Out:
# Result:
# Name: Pranjal
# Class: 2nd year
# Total Marks: 381.0
# Percentage: 76.2

# %%
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

s3 = s1 + " " + s2

print(f"Combined String: ",s3)

print("Lower:", s3.lower())
print("Upper:", s3.upper())
print("Title:", s3.title())
print("Swapcase:", s3.swapcase())
print("Capitalize:", s3.capitalize())
print("Casefold:", s3.casefold())
print("Center:", s3.center(30))
print("Count of 'o':", s3.count('o'))
print("Ends with 'o':", s3.endswith('o'))
print("Find 'o':", s3.find('o'))
print("Is Alnum:", s3.isalnum())
print("Is Digit:", s3.isdigit())
print("Is Numeric:", s3.isnumeric())
print("Is Space:", s3.isspace())
# Out:
# Combined String:  hello PYTHON
# Lower: hello python
# Upper: HELLO PYTHON
# Title: Hello Python
# Swapcase: HELLO python
# Capitalize: Hello python
# Casefold: hello python
# Center:          hello PYTHON
# Count of 'o': 1
# Ends with 'o': False
# Find 'o': 4
# Is Alnum: False
# Is Digit: False
# Is Numeric: False
# Is Space: False

# %%
x = 13

x += 5
print("After += :", x)

x -= 3 
print("After -= :", x)

x *= 2 
print("After *= :", x)

x /= 4 
print("After /= :", x)

x %= 3 
print("After %= :", x)

x **= 2 
print("After **= :", x)

x //= 2 
print("After //= :", x)
# Out:
# After += : 18
# After -= : 15
# After *= : 30
# After /= : 7.5
# After %= : 1.5
# After **= : 2.25
# After //= : 1.0

# %%
name = input("Enter student name: ")
student_class = input("Enter class: ")

m1 = float(input("Enter marks for Subject 1: "))
m2 = float(input("Enter marks for Subject 2: "))
m3 = float(input("Enter marks for Subject 3: "))
m4 = float(input("Enter marks for Subject 4: "))
m5 = float(input("Enter marks for Subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = total / 5

print("Result:")
print("Name:", name)
print("Class:", student_class)
print("Total Marks:", total)
print("Percentage:", percentage)

if percentage >= 60:
    grade = 'A'
elif percentage >= 50:
    grade = 'B'
elif percentage >= 40:
    grade = 'C'
elif percentage >= 33:
    grade = 'D'
else:
    grade = 'Fail'

print("Grade:", grade)
# Out:
# Result:
# Name: Pranjal
# Class: 12th
# Total Marks: 360.0
# Percentage: 72.0
# Grade: A
